# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('test.csv')

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df['Age'].fillna(round(df.Age.mean()),inplace=True)

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df1 = df[df['Age']>=30]
df2 = df[df['Age']<30]

# %%
df1.shape
# Out:
# (233, 11)

# %%
df2.shape
# Out:
# (185, 11)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  233 non-null    int64
#  1   Pclass       233 non-null    int64
#  2   Name         233 non-null    object
#  3   Sex          233 non-null    object
#  4   Age          233 non-null    float64
#  5   SibSp        233 non-null    int64
#  6   Parch        233 non-null    int64
#  7   Ticket       233 non-null    object
#  8   Fare         232 non-null    float64
#  9   Cabin        65 non-null     object
#  10  Embarked     233 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 21.8+ KB

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          168
# Embarked         0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          168
# Embarked         0
# dtype: int64

# %%
df.Cabin.value_counts()
# Out:
# B57 B59 B63 B66    3
# B45                2
# C89                2
# C55 C57            2
# A34                2
#                   ..
# E52                1
# D30                1
# E31                1
# C62 C64            1
# C105               1
# Name: Cabin, Length: 76, dtype: int64

# %%
df1['Cabin'].fillna('Not Specified',inplace=True)
# Out:
# C:\Users\Nihar\AppData\Local\Temp\ipykernel_19580\73238646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Cabin'].fillna('Not Specified',inplace=True)

# %%
df1
# Out:
#      PassengerId  Pclass                              Name     Sex   Age  \
# 0            892       3                  Kelly, Mr. James    male  34.5
# 1            893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2            894       2         Myles, Mr. Thomas Francis    male  62.0
# 6            898       3              Connolly, Miss. Kate  female  30.0
# 10           902       3                  Ilieff, Mr. Ylio    male  30.0
# ..           ...     ...                               ...     ...   ...
# 413         1305       3                Spector, Mr. Woolf    male  30.0
# 414         1306       1      Oliva y Ocana, Dona. Fermina  female  39.0
# 415         1307       3      Saether, Mr. Simon Sivertsen    male  38.5
# 416         1308       3               Ware, Mr. Frederick    male  30.0
# 417         1309       3          Peter, Master. Michael J    male  30.0
#
#      SibSp  Parch              Ticket      Fare          Cabin Embarked
# ...

# %%
df3 = pd.concat([df2, df1], axis=0)

# %%
df3
# Out:
#      PassengerId  Pclass                                          Name  \
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                    Svensson, Mr. Johan Cervin
# 7            899       2                  Caldwell, Mr. Albert Francis
# 8            900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare          Cabin  \
# ...
